# %%
# 001

print ("Hello World")
# Out:
# Hello World

# %%
# 002

print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
# 003 

## 1. 문자열 안에 큰따옴표 추가하기 위해서는 작은따옴포를 둘러싸야함.
print('신씨가 소리질렀다. "도둑이야".')
## 2. \(역슬래쉬)를 사용하여 특수 문자 취급.
print("신씨가 소리질렀다. \"도둑이야\".")
# Out:
# 신씨가 소리질렀다. "도둑이야".
# 신씨가 소리질렀다. "도둑이야".

# %%
# 004

print("C:\\\\Windows")
# Out:
# C:\\Windows

# %%
# 005

print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
# 006

##쉼표로 추가시키면 가운데 띄어쓰기됨.
print("오늘은","일요일")
# Out:
# 오늘은 일요일

# %%
# 007

print("naver;kakao;sk;samsung")
# Out:
# naver;kakao;sk;samsung

# %%
# 008

print("naver/kakao/sk/samsung")
# Out:
# naver/kakao/sk/samsung

# %%
# 009

print("first",end=" ");print("second")
# Out:
# first second

# %%
# 010

string = "dk2jd923i1jdk2jd93jfd92jd918943jfd8923"

len(string)
# Out:
# 38

# %%
# 011

a = "3"
b = "4"
print(a+b)
# Out:
# 34

# %%
# 012

s = "hello"
t = "python"

print(s+"!",t)
# Out:
# hello! python

# %%
# 013

print("Hi"*3)
# Out:
# HiHiHi

# %%
# 014

print("-"*80)
# Out:
# --------------------------------------------------------------------------------

# %%
# 015

t1 = 'python'
t2 = 'java'

print((t1+" "+t2+" ")*4)
# Out:
# python java python java python java python java

# %%
# 016

print(20000*10)
# Out:
# 200000

# %%
# 017

print(2 + 2 * 3)
# Out:
# 8

# %%
# 018

a = "132"
print(type(a))
# Out:
# <class 'str'>

# %%
# 019

num_str = "720"
print(type(num_str))
num_str=int(num_str)
print(type(num_str))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# 020

num = 100
print(type(num))
num = str(num)
print(type(num))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 021

lang = 'python'
print(lang[0],lang[2])
# Out:
# p t

# %%
# 022

license_plate = "24가 2210"
## my solution
for x in range(4,0,-1) :
  print(license_plate[-x],end="")
## solution
print("\n")
print(license_plate[4:])
# Out:
# 2210
#
# 2210

# %%
# 023

string = "홀짝홀짝홀짝"
## my solution
for x in range(0,len(string)):
  if x % 2 == 0 :
    print(string[x],end="")
## solution    
print("\n"+string[::2])
print(string[1::2])
# Out:
# 홀홀홀
# 홀홀홀
# 짝짝짝

# %%
# 024

string = "PYTHON"

## my solution
for x in range(len(string)-1,-1,-1):
  print(string[x],end="")
## solution
print("\n"+string[::-1])
# Out:
# NOHTYP
# NOHTYP

# %%
# 025

phone_number = "010-1111-2222"
## split 함수 적용!
new_phone_number=phone_number.split("-")

for x in new_phone_number :
  print(x,end=" ")
# Out:
# 010 1111 2222

# %%
# 026
## mysolution
for x in new_phone_number :
  print(x,end="")
## solution 1
print("\n"+phone_number[0:3]+phone_number[4:8]+phone_number[9:13])
## solution 2
## sep함수 : 콤마로 구분된 문자열을 다르게 결합 가능
print(phone_number[0:3],phone_number[4:8],phone_number[9:13],sep="")
# Out:
# 01011112222
# 01011112222
# 01011112222

# %%
# 027

url = "http://sharebook.kr"
print(url[-2:])
# Out:
# kr

# %%
# 028

lang = 'python'
lang[0] = 'P' #기존에 생성한 문자는 변경할 수 없음! 새로운 문자열 생성해야됨.
print(lang)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-e7eb0374997b> in <module>()
#       1
#       2 lang = 'python'
# ----> 3 lang[0] = 'P'
#       4 print(lang)
#
# TypeError: 'str' object does not support item assignment

# %%
# 029

string = 'abcdfe2a354a32'
# replace 함수 사용!
string.replace('a','A')
# Out:
# 'Abcdfe2A354A32'

# %%
# 030

string = 'abcd'
string.replace('b','B') # 기존의 문자열 변경 X! 변경된 문자열을 새롭게 생성해줘야됨
new_string = string.replace('b','B')
print(string)
print(new_string)
# Out:
# abcd
# aBcd
